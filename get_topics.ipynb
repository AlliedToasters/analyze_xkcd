# %% [markdown]
# ## API Scrape
# After scraping explainxkcd.com the old fashioned way, I discovered I could use Media Wiki's built in API to query the database. I also discovered that xkcd.com has an EXTREMELY simple API to grab the data that I scraped from explainxkcd.com (you can just get a json with the title, title text, and transcript of each comic directly from his server). So I did a bunch of extra work for nothing, but I value the experience.
# <br><br>
# I went on to use the explainxkcd.com API to get topics for each comic. This was a little tricky because I was simultaneously struggling to learn XPATH syntax, api query sytax, and the particular way that explainxkcd's wiki is set up, all while hacking scrapy to do my bidding. I am very happy to have something that finally worked. <br><br>
#
# ## User's Note:
# If you want to run this script, you must restart the kernel to run each crawl. It's really built for my machine, since it depends on another json file from a different scrape.

# %%
import pandas as pd
import numpy as np
import scrapy
from scrapy.crawler import CrawlerProcess


class CatSpider(scrapy.Spider):
    name = "Cats"
    
    # Here is where we insert our API call.
    start_urls = [
        'https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Comics_by_topic&cmlimit=max'
        ]

    # Identifying the information we want from the query response and extracting it using xpath.
    def parse(self, response):
        yield {
            'topics': response.xpath('/api/query/categorymembers/cm/@title').extract()
            }
            
process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'all_topics.json',
    # Note that because we are doing API queries, the robots.txt file doesn't apply to us.
    'ROBOTSTXT_OBEY': False,
    'USER_AGENT': 'ThinkfulDataScienceBootcampCrawler (thinkful.com)',
    'AUTOTHROTTLE_ENABLED': True,
    'HTTPCACHE_ENABLED': True,
    'LOG_ENABLED': True,
})
                                         

# Starting the crawler with our spider.
process.crawl(CatSpider)
process.start()
print('Something happened!!')
# Out:
# 2018-01-17 02:56:05 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2018-01-17 02:56:05 [scrapy.utils.log] INFO: Overridden settings: {'AUTOTHROTTLE_ENABLED': True, 'FEED_FORMAT': 'json', 'FEED_URI': 'all_topics.json', 'HTTPCACHE_ENABLED': True, 'USER_AGENT': 'ThinkfulDataScienceBootcampCrawler (thinkful.com)'}
# 2018-01-17 02:56:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2018-01-17 02:56:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats',
#  'scrapy.downloadermiddlewares.httpcache.HttpCacheMiddleware']
# 2018-01-17 02:56:05 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-01-17 02:56:05 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-01-17 02:56:05 [scrapy.core.engine] INFO: Spider opened
# 2018-01-17 02:56:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-01-17 02:56:05 [scrapy.extensions.httpcache] DEBUG: Using filesystem cache storage in .scrapy/httpcache
# 2018-01-17 02:56:05 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-01-17 02:56:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Comics_by_topic&cmlimit=max> (referer: None) ['cached']
# 2018-01-17 02:56:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Comics_by_topic&cmlimit=max>
# {'topics': ['Category:Airships', 'Category:Animals', 'Category:Banned from conferences', "Category:Beret Guy's Business", 'Category:Boomerangs', 'Category:Butterfly net', 'Category:Charts', 'Category:Clickbait', 'Category:Climate change', 'Category:Cancer', 'Category:Compromise', 'Category:Computers', 'Category:Conspiracy theory', 'Category:Crossbows', 'Category:Dreams', 'Category:Drones', 'Category:Dvorak', 'Category:Electric skateboard', 'Category:Elevators', 'Category:Emoji', 'Category:FernGully', 'Category:Fiction', 'Category:Food', 'Category:Fun fact', 'Category:Furries', 'Category:Google Glass', 'Category:Hamster Ball', 'Category:Holidays', 'Category:Homosexuality', 'Category:Humanities', 'Category:Hurricanes', 'Category:Job interviews', 'Category:Kites', 'Category:Language', 'Category:Logic', 'Category:Man pages', 'Category:Mars rovers', 'Category:Math', 'Category:Music', 'Category:My Hobby', 'Category:News anchor', 'Category:Optimization', 'Category:Pedantic', 'Category:Penis', 'Category:Pet Peeves', 'Category:Playpen balls', 'Category:Protip', 'Category:Public speaking', 'Category:Puns', 'Category:Puts on sunglasses', 'Category:Rankings', 'Category:Recursion', 'Category:Rickrolling', 'Category:Robots', 'Category:Romance', 'Category:Roomba', 'Category:Sarcasm', 'Category:Science', 'Category:Self-driving cars', 'Category:Sex', 'Category:Sheeple', 'Category:Smartphones', 'Category:Space', 'Category:Space probes', 'Category:Spice Girls', 'Category:Sport', 'Category:Strange powers of Beret Guy', 'Category:Substitutions', 'Category:Supermoon', 'Category:Time', 'Category:Tips', 'Category:Tornadoes', 'Category:Total Solar Eclipse 2017', 'Category:Traffic light', 'Category:Trebuchet', 'Category:Tribute', 'Category:Unicode', 'Category:Video games', 'Category:Virtual Assistants', 'Category:Wind turbine', 'Category:Wingsuit', 'Category:Your Mom', 'Category:Your sister']}
# 2018-01-17 02:56:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-01-17 02:56:05 [scrapy.extensions.feedexport] INFO: Stored json feed (1 items) in: all_topics.json
# 2018-01-17 02:56:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 335,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 1556,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 1, 17, 5, 56, 5, 828566),
#  'httpcache/hit': 1,
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 8,
#  'memusage/max': 81936384,
#  'memusage/startup': 81936384,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2018, 1, 17, 5, 56, 5, 691505)}
# 2018-01-17 02:56:05 [scrapy.core.engine] INFO: Spider closed (finished)
# Something happened!!

# %%
import pandas as pd
import numpy as np

# %%
tpx = pd.read_json('all_topics.json')
topics = pd.DataFrame()
topics['topic'] = tpx.loc[0].topics
topics['topic'] = topics.topic.apply(lambda x: x[9:])

# %%
df = pd.read_csv('cleaned_data.csv')
df.index = df.comic_number

# %%
def replace_space(string):
    if ' ' in string:
        string = string.replace(' ', '_')
    return string
        
topics['topic_'] = topics.topic.apply(replace_space)
topic_urls = iter(topics.topic_)

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class TopicCrawlSpider(scrapy.Spider):
    name = "topic_crawl"
    
    # Here is where we insert our API call.
    next_topic = next(topic_urls)
    start_urls = [
        'https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:{}&cmlimit=max'.format(next_topic)
        ]

    # Identifying the information we want from the query response and extracting it using xpath.
    def parse(self, response):
        yield {
            'comics': response.xpath('/api/query/categorymembers/cm/@title').extract()
            }
        
        try:
            next_topic = 'https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:{}&cmlimit=max'.format(next(topic_urls))
            next_page = response.urljoin(next_topic)
            # Request the next page and recursively parse it the same way we did above
            yield scrapy.Request(next_page, callback=self.parse)
        except:
            pass
        
            
process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'comics_by_topic.json',
    # Note that because we are doing API queries, the robots.txt file doesn't apply to us.
    'ROBOTSTXT_OBEY': False,
    'USER_AGENT': 'ThinkfulDataScienceBootcampCrawler (thinkful.com)',
    'AUTOTHROTTLE_ENABLED': True,
    'HTTPCACHE_ENABLED': True,
    'LOG_ENABLED': True,
})
                                         

# Starting the crawler with our spider.
process.crawl(TopicCrawlSpider)
process.start()
print('Something happened!!')
# Out:
# 2018-01-17 10:52:57 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2018-01-17 10:52:57 [scrapy.utils.log] INFO: Overridden settings: {'AUTOTHROTTLE_ENABLED': True, 'FEED_FORMAT': 'json', 'FEED_URI': 'comics_by_topic.json', 'HTTPCACHE_ENABLED': True, 'USER_AGENT': 'ThinkfulDataScienceBootcampCrawler (thinkful.com)'}
# 2018-01-17 10:52:57 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2018-01-17 10:52:57 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats',
#  'scrapy.downloadermiddlewares.httpcache.HttpCacheMiddleware']
# 2018-01-17 10:52:57 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-01-17 10:52:57 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-01-17 10:52:57 [scrapy.core.engine] INFO: Spider opened
# 2018-01-17 10:52:57 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-01-17 10:52:57 [scrapy.extensions.httpcache] DEBUG: Using filesystem cache storage in .scrapy/httpcache
# 2018-01-17 10:52:57 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-01-17 10:52:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Airships&cmlimit=max> (referer: None) ['cached']
# 2018-01-17 10:52:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Airships&cmlimit=max>
# {'comics': ['73: Zeppelin', '235: Kite', '288: Elevator', '430: Every Damn Morning', '495: Secretary: Part 2', '497: Secretary: Part 4', '992: Mnemonics']}
# 2018-01-17 10:52:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Animals&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Airships&cmlimit=max) ['cached']
# 2018-01-17 10:52:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Animals&cmlimit=max>
# {'comics': ['26: Fourier', '28: Elefino', '35: Sheep', '68: Five Thirty', '115: Meerkat', '135: Substitute', '141: Parody Week: Achewood', '143: Parody Week: TFD and Natalie Dee', '204: America', '231: Cat Proximity', '260: The Glass Necklace', '370: Redwall', '378: Real Programmers', '427: Bad Timing', '435: Purity', '482: Height', '510: Egg Drop Failure', '520: Cuttlefish', "571: Can't Sleep", '589: Designated Drivers', '683: Science Montage', '752: Phobia', '772: Frogger', '867: Herpetology', '877: Beauty', '890: Etymology', '915: Connoisseur', '926: Time Vulture', '928: Mimic Octopus', '1000: 1000 Comics', '1012: Wrong Superhero', '1022: So It Has Come To This', '1025: Tumblr', '1031: s/keyboard/leopard/', '1036: Reviews', "1052: Every Major's Terrible", '1056: Felidae', '1062: Budget News', '1064: Front Door', '1079: United Shapes', '1086: Eyelash Wish Log', '1104: Feathers', '1134: Logic Boat', '1156: Conditioning', '1193: Externalities', '1240: Quantum Mechanics', '1249: Meteor Showers', '1256: Questions', '1257: Monster', '1268: Alternate Universe', '1288: Substitutions', '1329: Standing', '1338: Land Mammals', '1350: Lorenz', '1376: Jump', '1398: Snake Facts', '1408: March of the Penguins', '1434: Where Do Birds Go', '1439: Rack Unit', '1440: Geese', '1446: Landing', '1461: Payloads', '1465: xkcd Phone 2', '1471: Gut Fauna', '1510: Napoleon', '1515: Basketball Earth', '1519: Venus', '1527: Humans', '1535: Words for Pets', '1552: Rulebook', '1556: The Sky', '1558: Vet', '1565: Back Seat', '1575: Footprints', '1596: Launch Status Check', '1604: Snakes', '1608: Hoverboard', '1610: Fire Ants', '1614: Kites', '1620: Christmas Settings', '1625: Substitutions 2', '1628: Magnus', '1632: Palindrome', '1633: Possible Undiscovered Planets', '1635: Birdsong', '1640: Super Bowl Context', '1645: Toasts', '1649: Pipelines', '1656: It Begins', '1663: Garden', '1664: Mycology', '1675: Message in a Bottle', '1676: Full-Width Justification', '1682: Bun', '1684: Rainbow', '1688: Map Age Guide', '1689: My Friend Catherine', '1692: Man Page', '1693: Oxidation', '1695: Code Quality 2', '1702: Home Itch Remedies', '1705: Pokémon Go', '1706: Genetic Testing', '1707: xkcd Phone 4', '1710: Walking Into Things', '1713: 50 ccs', '1714: Volcano Types', '1719: Superzoom', '1720: Horses', '1725: Linear Regression', '1729: Migrating Geese', '1732: Earth Temperature Timeline', '1746: Making Friends', '1747: Spider Paleontology', '1749: Mushrooms', '1750: Life Goals', '1776: Reindeer', '1786: Trash', '1792: Bird/Plane/Superman', '1795: All You Can Eat', '1797: Stardew Valley', '1819: Sweet 16', '1824: Identification Chart', '1826: Birdwatching', '1829: Geochronology', '1842: Anti-Drone Eagles', '1871: Bun Alert', '1879: Eclipse Birds', '1903: Bun Trend', '1904: Research Risks', '1910: Sky Spotters', '1922: Interferometry', '1924: Solar Panels', '1932: The True Meaning of Christmas', '1933: Santa Facts', 'Category:Apatosaurus', 'Category:Bobcats', 'Category:Butterfly net', 'Category:Dinosaurs', 'Category:Ferret', 'Category:Giraffes', 'Category:Hamster Ball', 'Category:Red Spiders', 'Category:Sharks', 'Category:Spiders', 'Category:Squirrels', 'Category:Velociraptors']}
# 2018-01-17 10:52:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Banned_from_conferences&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Animals&cmlimit=max) ['cached']
# 2018-01-17 10:52:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Banned_from_conferences&cmlimit=max>
# {'comics': ['153: Cryptography', '177: Alice and Bob', '365: Slides', '410: Math Paper', '463: Voting Machines', '541: TED Talk']}
# 2018-01-17 10:52:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Beret_Guy's_Business&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Banned_from_conferences&cmlimit=max) ['cached']
# 2018-01-17 10:52:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Beret_Guy's_Business&cmlimit=max>
# {'comics': ['1021: Business Plan', '1032: Networking', '1117: My Sky', '1293: Job Interview', '1493: Meeting', '1533: Antique Factory', '1772: Startup Opportunity', '1812: Onboarding', '1871: Bun Alert']}
# 2018-01-17 10:52:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Boomerangs&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Beret_Guy's_Business&cmlimit=max) ['cached']
# 2018-01-17 10:52:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Boomerangs&cmlimit=max>
# {'comics': ['445: I Am Not Good with Boomerangs', '475: Further Boomerang Difficulties', '939: Arrow', '1000: 1000 Comics', '1350: Lorenz']}
# 2018-01-17 10:52:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Butterfly_net&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Boomerangs&cmlimit=max) ['cached']
# 2018-01-17 10:52:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Butterfly_net&cmlimit=max>
# {'comics': ['1110: Click and Drag', '1193: Externalities', '1243: Snare', '1523: Microdrones', '1622: Henge', '1635: Birdsong']}
# 2018-01-17 10:52:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:
58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Clickbait&cmlimit=max>
# {'comics': ['1283: Headlines', '1307: Buzzfeed Christmas', '1426: Reduce Your Payments', '1511: Spice Girl', '1608: Hoverboard']}
# 2018-01-17 10:52:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Climate_change&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Clickbait&cmlimit=max) ['cached']
# 2018-01-17 10:52:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Climate_change&cmlimit=max>
# {'comics': ["164: Playing Devil's Advocate to Win", '603: Idiocracy', '887: Future Timeline', '980: Money', '1225: Ice Sheets', '1321: Cold', '1379: 4.5 Degrees', '1412: Teenage Mutant Ninja Turtles', '1659: Tire Swing', '1732: Earth Temperature Timeline', '1812: Onboarding']}
# 2018-01-17 10:52:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Cancer&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Climate_change&cmlimit=max) ['cached']
# 2018-01-17 10:52:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Cancer&cmlimit=max>
# {'comics': ['818: Illness', '836: Sickness', '881: Probability', '925: Cell Phones', '931: Lanes', '933: Tattoo', '938: T-Cells', '996: Making Things Difficult', '1048: Emotion', '1114: Metallurgy', '1141: Two Years', '1217: Cells', '1331: Frequency', '1355: Airplane Message', '1736: Manhattan Project', '1928: Seven Years']}
# 2018-01-17 10:52:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Compromise&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Cancer&cmlimit=max) ['cached']
# 2018-01-17 10:52:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Compromise&cmlimit=max>
# {'comics': ['690: Semicontrolled Demolition', '1070: Words for Small Sets', '1167: Star Trek into Darkness', '1285: Third Way', '1292: Pi vs. Tau', '1923: Felsius']}
# 2018-01-17 10:52:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Computers&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Compromise&cmlimit=max) ['cached']
# 2018-01-17 10:52:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Computers&cmlimit=max>
# {'comics': ['86: Digital Rights Management', '177: Alice and Bob', '221: Random Number', '224: Lisp', '225: Open Source', '234: Escape Artist', '243: Appropriate Term', '251: CD Tray Fight', '297: Lisp Cycles', '327: Exploits of a Mom', '329: Turing Test', '341: 1337: Part 1', '342: 1337: Part 2', '343: 1337: Part 3', '344: 1337: Part 4', '345: 1337: Part 5', '349: Success', '371: Compiler Complaint', '376: Bug', '380: Emoticon', '394: Kilobyte', '416: Zealous Autoconfig', '424: Security Holes', '463: Voting Machines', '466: Moving', '518: Flow Charts', '528: Windows 7', "530: I'm An Idiot", '533: Laptop Hell', '597: Addiction', '601: Game Theory', '607: 2038', '609: Tab Explosion', '612: Estimation', '644: Surgery', '648: Fall Foliage', '672: Suggestions', '676: Abstraction', '686: Admin Mourning', '722: Computer Problems', '726: Seat Selection', '727: Trade Expert', '763: Workaround', '806: Tech Support', '858: Milk', '869: Server Attention Span', '894: Progeny', '932: CIA', '934: Mac/PC', '936: Password Strength', '937: TornadoGuard', '948: AI', '949: File Transfer', '958: Hotels', '963: X11', '981: Porn Folder', '1000: 1000 Comics', '1024: Error Code', "1052: Every Major's Terrible", '1056: Felidae', '1077: Home Organization', '1083: Writing Styles', '1084: Server Problem', '1118: Microsoft', '1137: RTL', '1143: Location', '1168: tar', '1172: Workflow', '1174: App', '1180: Virus Venn Diagram', '1197: All Adobe Updates', '1200: Authorization', '1223: Dwarf Fortress', '1224: Council of 300', '1229: Screensaver', '1247: The Mother of All Suspicious Files', '1250: Old Accounts', '1263: Reassuring', '1266: Halting Problem', '1269: Privacy Opinions', '1306: Sigil Cycle', '1316: Inexplicable', '1323: Protocol', '1328: Update', '1337: Hack', "1349: Shouldn't Be Hard", '1350: Lorenz', '1353: Heartbleed', '1354: Heartbleed Explanation', '1367: Installing', '1401: New', '1406: Universal Converter Box', '1411: Loop', '1439: Rack Unit', '1479: Troubleshooting', '1495: Hard Reboot', '1506: xkcloud', '1508: Operating Systems', '1513: Code Quality', '1570: Engineer Syllogism', '1573: Cyberintelligence', '1579: Tech Loops', '1586: Keyboard Problems', '1597: Git', '1605: DNA', '1619: Watson Medical Algorithm', '1626: Judgment Day', '1627: Woosh', '1629: Tools', '1636: XKCD Stack', '1646: Twitter Bot', '1668: Singularity', '1683: Digital Data', '1690: Time-Tracking Software', '1692: Man Page', '1695: Code Quality 2', '1696: AI Research', '1700: New Bug', '1718: Backups', '1722: Debugging', '1727: Number of Computers', '1728: Cron Mail', '1737: Datacenter Scale', '1739: Fixing Problems', '1760: TV Problems', '1764: XKCDE', '1765: Baby Post', '1782: Team Chat', '1785: Wifi', '1805: Unpublished Discoveries', '1806: Borrow Your Laptop', '1808: Hacking', '1817: Incognito Mode', '1820: Security Advice', '1822: Existential Bug Reports', '1823: Hottest Editors', '1833: Code Quality 3', '1854: Refresh Types', '1875: Computers vs Humans', '1886: Typing Notifications', '1888: Still in Use', '1891: Obsolete Technology', '1912: Thermostat', '1926: Bad Code', '1938: Meltdown and Spectre', 'Category:Artificial Intelligence', 'Category:BSD', 'Category:Computer security', 'Category:Emacs', 'Category:Identity Theft', 'Category:Internet', 'Category:Linux', 'Category:Programming', 'Category:Singularity']}
# 2018-01-17 10:52:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Conspiracy_theory&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Computers&cmlimit=max) ['cached']
# 2018-01-17 10:52:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Conspiracy_theory&cmlimit=max>
# {'comics': ['250: Snopes', '258: Conspiracy Theories', '690: Semicontrolled Demolition', '966: Jet Fuel', '1081: Argument Victory', '1224: Council of 300', '1274: Open Letter', '1400: D.B. Cooper', '1664: Mycology', '1677: Contrails', '1717: Pyramid Honey', '1803: Location Reviews']}
# 2018-01-17 10:52:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Crossbows&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Conspiracy_theory&cmlimit=max) ['cached']
# 2018-01-17 10:52:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Crossbows&cmlimit=max>
# {'comics': ['190: IPoD', '337: Post Office Showdown', '476: One-Sided', '564: Crossbows', '929: Speculation']}
# 2018-01-17 10:52:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Dreams&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Crossbows&cmlimit=max) ['cached']
# 2018-01-17 10:52:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Dreams&cmlimit=max>
# {'comics': ['137: Dreams', '203: Hallucinations', '240: Dream Girl', '269: TCMP', '390: Nightmares', '430: Every Damn Morning', '520: Cuttlefish', '557: Students', '622: Haiku Proof', '719: Brain Worms', '800: Beautiful Dream', '806: Tech Support', '1023: Late-Night PBS', '1350: Lorenz', '1376: Jump', '1538: Lyrics']}
# 2018-01-17 10:52:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Drones&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Dreams&cmlimit=max) ['cached']
# 2018-01-17 10:52:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Drones&cmlimit=max>
# {'comics': ['652: More Accurate', '1207: AirAware', '1358: NRO', '1523: Microdrones', '1608: Hoverboard', '1630: Quadcopter', '1842: Anti-Drone Eagles', '1846: Drone Problems', '1858: 4th of July', '1881: Drone Training', '1883: Supervillain Plan', '1910: Sky Spotters']}
# 2018-01-17 10:52:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:
', '1318: Actually', '1322: Winter', '1339: When You Assume', '1383: Magic Words', '1385: Throwing Rocks', '1396: Actors', '1401: New', '1412: Teenage Mutant Ninja Turtles', '1414: Writing Skills', '1418: Horse', '1424: En Garde', '1427: iOS Keyboard', '1429: Data', '1443: Language Nerd', '1460: SMFW', '1483: Quotative Like', '1513: Code Quality', '1531: The BDLPSWDKS Effect', '1535: Words for Pets', '1537: Types', '1562: I in Team', '1571: Car Model Names', '1575: Footprints', '1576: I Could Care Less', '1602: Linguistics Club', '1621: Fixion', '1625: Substitutions 2', '1627: Woosh', '1632: Palindrome', '1645: Toasts', '1647: Diacritics', '1652: Conditionals', '1661: Podium', '1677: Contrails', '1679: Substitutions 3', '1695: Code Quality 2', '1697: Intervocalic Fortition', '1709: Inflection', '1734: Reductionism', '1735: Fashion Police and Grammar Police', '1771: It Was I', '1816: Mispronunciation', '1849: Decades', '1932: The True Meaning of Christmas', 'Category:Emoji', 'Category:Portmanteau', 'Category:Programming', 'Category:Puns', 'Category:Sarcasm', 'Category:Simplified language', 'Category:Unicode']}
# 2018-01-17 10:53:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Logic&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Language&cmlimit=max) ['cached']
# 2018-01-17 10:53:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Logic&cmlimit=max>
# {'comics': ['74: Su Doku', '246: Labyrinth Puzzle', '589: Designated Drivers', '658: Orbitals', '703: Honor Societies', '704: Principle of Explosion', '804: Pumpkin Carving', '816: Applied Math', '832: Tic-Tac-Toe', '982: Set Theory', '1033: Formal Logic', '1090: Formal Languages', '1134: Logic Boat', '1332: Slippery Slope', '1570: Engineer Syllogism', '1576: I Could Care Less', '1579: Tech Loops', 'Category:Programming']}
# 2018-01-17 10:53:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Man_pages&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Logic&cmlimit=max) ['cached']
# 2018-01-17 10:53:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Man_pages&cmlimit=max>
# {'comics': ['293: RTFM', '434: xkcd Goes to the Airport', '456: Cautionary', '912: Manual Override', '1343: Manuals', '1692: Man Page']}
# 2018-01-17 10:53:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Mars_rovers&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Man_pages&cmlimit=max) ['cached']
# 2018-01-17 10:53:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Mars_rovers&cmlimit=max>
# {'comics': ['665: Prudence', '681: Gravity Wells', '695: Spirit', '1091: Curiosity', '1428: Move Fast and Break Things', '1436: Orb Hammer', '1461: Payloads', '1504: Opportunity', '1585: Similarities', '1613: The Three Laws of Robotics', '1663: Garden', '1757: November 2016']}
# 2018-01-17 10:53:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Math&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Mars_rovers&cmlimit=max) ['cached']
# 2018-01-17 10:53:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Math&cmlimit=max>
# {'comics': ['5: Blown apart', '10: Pi Equals', '12: Poisson', '19: George Clinton', '26: Fourier', '28: Elefino', '54: Science', '55: Useless', '62: Valentine - Karnaugh', '68: Five Thirty', '74: Su Doku', '85: Paths', '88: Escher Bracelet', '89: Gravitational Mass', '95: The Sierpinski Penis Game', '112: Baring My Heart', '113: Riemann-Zeta', '128: dPain over dt', '135: Substitute', '173: Movie Seating', '179: e to the pi times i', '183: Snacktime Rules', '184: Matrix Transform', '199: Right-Hand Rule', '207: What xkcd Means', '216: Romantic Drama Equation', '217: e to the pi Minus pi', '230: Hamiltonian', '247: Factoring the Time', '263: Certainty', '287: NP-Complete', '289: Alone', '314: Dating Pools', '356: Nerd Sniping', '385: How it Works', '399: Travelling Salesman Problem', '403: Convincing Pickup Line', '410: Math Paper', '435: Purity', '447: Too Old For This Shit', '468: Fetishes', '487: Numerical Sex Positions', '539: Boyfriend', '563: Fermirotica', '569: Borders', '587: Crime Scene', '599: Apocalypse', '602: Overstimulated', '622: Haiku Proof', '626: Newton and Leibniz', '643: Ohm', '645: RPS', '687: Dimensional Analysis', '688: Self-Description', '701: Science Valentine', '704: Principle of Explosion', '710: Collatz Conjecture', '718: The Flake Equation', '721: Flatland', '759: 3x9', '775: Savannah Ancestry', '804: Pumpkin Carving', '809: Los Alamos', '824: Guest Week: Bill Amend (FoxTrot)', '833: Convincing', '849: Complex Conjugate', '866: Compass and Straightedge', '870: Advertising', '872: Fairy Tales', '881: Probability', '893: 65 Years', '896: Marie Curie', '899: Number Line', '900: Religions', '904: Sports', '925: Cell Phones', '936: Password Strength', '946: Family Decals', '947: Investing', '953: 1 to 10', '982: Set Theory', '985: Percentage Points', '992: Mnemonics', '1000: 1000 Comics', '1017: Backward in Time', '1033: Formal Logic', '1047: Approximations', '1050: Forgot Algebra', "1052: Every Major's Terrible", '1053: Ten Thousand', '1090: Formal Languages', '1131: Math', '1132: Frequentists vs. Bayesians', '1155: Kolmogorov Directions', '1159: Countdown', '1161: Hand Sanitizer', '1162: Log Scale', '1179: ISO 8601', '1184: Circumference Formula', '1201: Integration by Parts', '1205: Is It Worth the Time?', '1213: Combination Vision Test', '1230: Polar/Cartesian', '1236: Seashell', '1252: Increased Risk', '1275: int(pi)', '1276: Angular Size', '1277: Ayn Random', '1292: Pi vs. Tau', "1299: I Don't Own a TV", '1310: Goldbach Conjectures', '1344: Digits', '1374: Urn', '1381: Margin', '1399: Chaos', '1516: Win by Induction', '1570: Engineer Syllogism', '1571: Car Model Names', '1574: Trouble for Science', '1696: AI Research', '1724: Proofs', '1725: Linear Regression', '1779: 2017', '1856: Existence Proof', '1885: Ensemble Model', '1923: Felsius', '1935: 2018', 'Category:Cryptography', 'Category:Logic', 'Category:Physics', 'Category:Statistics']}
# 2018-01-17 10:53:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Music&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Math&cmlimit=max) ['cached']
# 2018-01-17 10:53:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Music&cmlimit=max>
# ...
# 2018-01-17 10:53:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Sport&cmlimit=max>
# {'comics': ['115: Meerkat', '540: Base System', '588: Pep Rally', '696: Strip Games', '852: Local g', '929: Speculation', '1173: Steroids', '1249: Meteor Showers', '1424: En Garde', '1480: Super Bowl', '1507: Metaball', '1608: Hoverboard', '1628: Magnus', '1701: Speed and Danger', '1732: Earth Temperature Timeline', '1819: Sweet 16', '1859: Sports Knowledge', '1936: Desert Golfing', 'Five-Minute Comics: Part 4', 'Category:American football', 'Category:Baseball', 'Category:Basketball', 'Category:Chess', 'Category:Soccer']}
# 2018-01-17 10:53:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Strange_powers_of_Beret_Guy&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Sport&cmlimit=max) ['cached']
# 2018-01-17 10:53:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Strange_powers_of_Beret_Guy&cmlimit=max>
# {'comics': ['248: Hypotheticals', '452: Mission', '1088: Five Years', '1099: Tuesdays', '1135: Arachnoneurology', '1158: Rubber Sheet', '1293: Job Interview', '1388: Subduction License', '1395: Power Cord', '1422: My Phone is Dying', '1486: Vacuum', '1490: Atoms', '1522: Astronomy', '1614: Kites', '1617: Time Capsule', '1922: Interferometry']}
# 2018-01-17 10:53:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Substitutions&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Strange_powers_of_Beret_Guy&cmlimit=max) ['cached']
# 2018-01-17 10:53:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Substitutions&cmlimit=max>
# {'comics': ['821: Five-Minute Comics: Part 3', '1004: Batman', '1025: Tumblr', '1031: s/keyboard/leopard/', '1418: Horse', '1689: My Friend Catherine', 'Category:Substitution series']}
# 2018-01-17 10:53:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Supermoon&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Substitutions&cmlimit=max) ['cached']
# 2018-01-17 10:53:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Supermoon&cmlimit=max>
# {'comics': ["1052: Every Major's Terrible", '1080: Visual Field', '1394: Superm*n', '1880: Eclipse Review', '1930: Calendar Facts']}
# 2018-01-17 10:53:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Time&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Supermoon&cmlimit=max) ['cached']
# 2018-01-17 10:53:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Time&cmlimit=max>
# {'comics': ['926: Time Vulture', '994: Advent Calendar', '1061: EST', '1086: Eyelash Wish Log', '1190: Time', '1335: Now', '1491: Stories of the Past and Future', '1524: Dimensions', '1577: Advent', '1624: 2016', '1655: Doomsday Clock', '1658: Estimating Time', '1686: Feel Old', '1688: Map Age Guide', '1704: Gnome Ann', '1786: Trash', '1806: Borrow Your Laptop', '1822: Existential Bug Reports', '1849: Decades', '1930: Calendar Facts', '1935: 2018', 'Category:Daylight saving time', 'Category:Time management', 'Category:Comics to make one feel old', 'Category:Time travel']}
# 2018-01-17 10:53:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tips&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Time&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tips&cmlimit=max>
# {'comics': ['897: Elevator Inspection', '1215: Insight', '1567: Kitchen Tips', '1696: AI Research', '1715: Household Tips', '1754: Tornado Safety Tips', '1820: Security Advice', '1829: Geochronology', 'Category:Protip']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tornadoes&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tips&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tornadoes&cmlimit=max>
# {'comics': ['402: 1,000 Miles North', '640: Tornado Hunter', '752: Phobia', '937: TornadoGuard', '1037: Umwelt', '1472: Geography', '1487: Tornado', '1509: Scenery Cheat Sheet', '1624: 2016', '1754: Tornado Safety Tips', 'Five-Minute Comics: Part 4']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Total_Solar_Eclipse_2017&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tornadoes&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Total_Solar_Eclipse_2017&cmlimit=max>
# {'comics': ['1302: Year in Review', '1779: 2017', '1868: Eclipse Flights', '1876: Eclipse Searches', '1877: Eclipse Science', '1878: Earth Orbital Diagram', '1879: Eclipse Birds', '1880: Eclipse Review', '1887: Two Down, One to Go', '1928: Seven Years']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Traffic_light&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Total_Solar_Eclipse_2017&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Traffic_light&cmlimit=max>
# {'comics': ['165: Turn Signals', '207: What xkcd Means', '277: Long Light', '1116: Traffic Lights']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Trebuchet&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Traffic_light&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Trebuchet&cmlimit=max>
# {'comics': ['382: Trebuchet', '1160: Drop Those Pounds', '1190: Time', '1378: Turbine']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tribute&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Trebuchet&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tribute&cmlimit=max>
# {'comics': ['393: Ultimate Game', '961: Eternal Flame', '1234: Douglas Engelbart (1925-2013)', '1498: Terry Pratchett', '1560: Bubblegum']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Unicode&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Tribute&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Unicode&cmlimit=max>
# {'comics': ['380: Emoticon', '1137: RTL', '1209: Encoding', '1676: Full-Width Justification', '1700: New Bug', '1726: Unicode', '1813: Vomiting Emoji', '1857: Emoji Movie', '1913: A ?', 'Category:Emoji']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Video_games&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Unicode&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Video_games&cmlimit=max>
# {'comics': ['50: Penny Arcade', '53: Hobby', '70: Guitar Hero', '83: Katamari', '91: Pwned', '117: Pong', '127: The Fast and the Furious', '132: Music Knowledge', '151: Mario', '160: Penny Arcade Parody', '161: Accident', '186: Console Lines', '188: Reload', '189: Exercise', '218: Nintendo Surgeon', '290: Fucking Blue Shells', '296: Tony Hawk', '299: Aeris Dies', '347: Brick Archway', '359: Rock Band', '375: Pod Bay Doors', '409: Electric Skateboard (Double Comic)', '423: Finish Line', '480: Spore', '484: Flash Games', '506: Theft of the Magi', '569: Borders', '574: Swine Flu', '606: Cutting Edge', '621: Superlative', '623: Oregon', '637: Scribblenauts', '654: Nachos', '667: SkiFree', '721: Flatland', '724: Hell', '744: Walkthrough', '746: Birth', '772: Frogger', '788: The Carriage', '792: Password Reuse', '841: Audiophiles', '851: Na', '861: Wisdom Teeth', '873: FPS Mod', '882: Significant', '888: Heaven', '969: Delta-P', '983: Privacy', '1002: Game AIs', '1037: Umwelt', '1086: Eyelash Wish Log', '1106: ADD', '1110: Click and Drag', '1141: Two Years', '1143: Location', '1223: Dwarf Fortress', '1244: Six Words', '1247: The Mother of All Suspicious Files', '1288: Substitutions', '1344: Digits', '1356: Orbital Mechanics', '1516: Win by Induction', '1608: Hoverboard', '1636: XKCD Stack', '1648: Famous Duos', '1684: Rainbow', '1750: Life Goals', '1757: November 2016', '1767: US State Names', '1790: Sad', '1797: Stardew Valley', '1819: Sweet 16', '1936: Desert Golfing', 'Category:Guitar Hero', 'Category:Katamari Damacy', 'Category:Mario Kart', 'Category:Pokémon']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Virtual_Assistants&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Video_games&cmlimit=max) ['cached']
# 2018-01-17 10:53:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Virtual_Assistants&cmlimit=max>
# {'comics': ['1363: xkcd Phone', '1707: xkcd Phone 4', '1807: Listening', '1931: Virtual Assistant']}
# 2018-01-17 10:53:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Wind_turbine&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Virtual_Assistants&cmlimit=max) ['cached']
# 2018-01-17 10:53:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Wind_turbine&cmlimit=max>
# {'comics': ['556: Alternative Energy Revolution', '1119: Undoing', '1378: Turbine']}
# 2018-01-17 10:53:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Wingsuit&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Wind_turbine&cmlimit=max) ['cached']
# 2018-01-17 10:53:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Wingsuit&cmlimit=max>
# {'comics': ['620: Wings', '962: The Corliss Resolution', '1051: Visited', '1110: Click and Drag']}
# 2018-01-17 10:53:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Your_Mom&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Wingsuit&cmlimit=max) ['cached']
# 2018-01-17 10:53:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Your_Mom&cmlimit=max>
# {'comics': ["61: Stacey's Dad", '65: Banter', '89: Gravitational Mass', '116: City', '158: Six Months', '176: Before Sunrise', '294: Bookstore', '320: 28-Hour Day', '345: 1337: Part 5', '366: Your Mom', '502: Dark Flow', '526: Converting to Metric', '541: TED Talk', '563: Fermirotica', '639: Lincoln-Douglas', '680: December 25th', '681: Gravity Wells', '713: GeoIP', '775: Savannah Ancestry', '785: Open Mic Night', '819: Five-Minute Comics: Part 1', '1037: Umwelt']}
# 2018-01-17 10:53:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Your_sister&cmlimit=max> (referer: https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Your_Mom&cmlimit=max) ['cached']
# 2018-01-17 10:53:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.explainxkcd.com/wiki/api.php?action=query&format=xml&list=categorymembers&cmtitle=Category:Your_sister&cmlimit=max>
# {'comics': ['49: Want', '273: Electromagnetic Spectrum', '279: Pickup Lines', "317: That Lovin' Feelin'"]}
# 2018-01-17 10:53:07 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-01-17 10:53:07 [scrapy.extensions.feedexport] INFO: Stored json feed (83 items) in: comics_by_topic.json
# 2018-01-17 10:53:07 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 43583,
#  'downloader/request_count': 83,
#  'downloader/request_method_count/GET': 83,
#  'downloader/response_bytes': 67936,
#  'downloader/response_count': 83,
#  'downloader/response_status_count/200': 83,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 1, 17, 13, 53, 7, 433228),
#  'httpcache/hit': 83,
#  'item_scraped_count': 83,
#  'log_count/DEBUG': 168,
#  'log_count/INFO': 8,
#  'memusage/max': 108711936,
#  'memusage/startup': 108711936,
#  'request_depth_max': 82,
#  'response_received_count': 83,
#  'scheduler/dequeued': 83,
#  'scheduler/dequeued/memory': 83,
#  'scheduler/enqueued': 83,
#  'scheduler/enqueued/memory': 83,
#  'start_time': datetime.datetime(2018, 1, 17, 13, 52, 57, 583461)}
# 2018-01-17 10:53:07 [scrapy.core.engine] INFO: Spider closed (finished)
# Something happened!!

# %%
topics_by_comic = pd.read_json('comics_by_topic.json')
topics_by_comic.index = topics.index
topics['comics'] = topics_by_comic

# %%
for row in topics.index:
    topic = topics.loc[row].topic_
    comics = topics.loc[row].comics
    df[topic] = 0
    for comic in comics:
        try:
            number = int(comic.split(':')[0])
        except:
            break
        df.at[number, topic] = 1

# %%
df["Banned_from_conferences"].sum()
# Out:
# 6.0

# %%
tpx = list(topics.topic_)
topics['no_comics'] = list(df[tpx].sum(axis=0))

# %%
print('most popular topic: ', topics.loc[topics.no_comics.idxmax()].topic)
print('most rare topic: ', topics.loc[topics[topics.no_comics > 0].no_comics.idxmin()].topic)
# Out:
# most popular topic:  Computers
# most rare topic:  Optimization

# %%
df = df[df.comic_number.notnull()].copy()
df.comic_number = df.comic_number.apply(int)
df.to_csv('comics_and_topics.csv', index=False)
